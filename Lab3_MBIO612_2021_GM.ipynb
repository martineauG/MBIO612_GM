# %% [markdown]
# #  Homework 2
# ## MBIO612
# ### Gabrielle Martineau

# %% [markdown]
# ## Question 1: Provide at least two methods to view the number of of rows and the number of columsn in the `mpg` dataset

# %%
#Install necessary packages and librairies

install.packages ("tidyverse")
library(tidyverse)
library (ggplot2)

data(mpg)


## First way to calculate
nrow(mpg)    
ncol(mpg)

##Second way to calculate
#Look at the size of the tibble with the function str
str(mpg)
# Out:
# Installing package into 'C:/Users/Martine/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# Warning message:
# "package 'tidyverse' is in use and will not be installed"
# [1] 234
# [1] 11
# tibble [234 x 11] (S3: tbl_df/tbl/data.frame)
#  $ manufacturer: chr [1:234] "audi" "audi" "audi" "audi" ...
#  $ model       : chr [1:234] "a4" "a4" "a4" "a4" ...
#  $ displ       : num [1:234] 1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year        : int [1:234] 1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl         : int [1:234] 4 4 4 4 6 6 6 4 4 4 ...
#  $ trans       : chr [1:234] "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv         : chr [1:234] "f" "f" "f" "f" ...
#  $ cty         : int [1:234] 18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy         : int [1:234] 29 29 31 30 26 26 27 26 25 28 ...
#  $ fl          : chr [1:234] "p" "p" "p" "p" ...
#  $ class       : chr [1:234] "compact" "compact" "compact" "compact" ...

# %% [markdown]
# ## Question 2: What is wrong with the code?

# %%
 ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = "blue"))
  
  #The color value needs to be outside the Aes

  ggplot(data = mpg) + 
    geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## Question 3: Change the code below so that mpg$class_numeric will be of type integer (int) rather than double (dbl)

# %%
mpg$class_numeric = sapply(mpg$class, convert_class_int, USE.NAMES = FALSE)
# Out:
# Error in match.fun(FUN): object 'convert_class_int' not found
# Traceback:
#
# 1. sapply(mpg$class, convert_class_int, USE.NAMES = FALSE)
# 2. match.fun(FUN)

# %% [markdown]
# ## Question 4

# %%
  ggplot (data=mpg,aes (cty, hwy))+         
            geom_point(aes(colour= class), size= 6)+
    geom_smooth (method=lm, se=TRUE, colour= "red")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# ## Question 5

# %%
  mpg_subcompact_subset = mpg[which(mpg$class=="subcompact"),]
  mpg_subcompact_subset_15 = mpg_subcompact_subset[which(mpg_subcompact_subset$cty == 15),]
mpg_subcompact_subset_15 %>% 
  select(manufacturer, model)
# Out:
#   manufacturer model
# 1 ford         mustang
# 2 ford         mustang
# 3 ford         mustang
# 4 ford         mustang

# %% [markdown]
# ## Question 6

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, shape=class))+
            scale_shape_manual (values =c(1:20))
# Out:
# plot without title

# %% [markdown]
# ## Question 7

# %%
Matrix_1 <- data.frame ("size"= c(3.385,0.48,1.35,465,36.33,27.66,14.83,1.04,4.19,0.425,0.101,0.92,1,0.005,0.06,3.5,2,1.7,2547,0.023,187.1,521,0.785,10,3.3,0.2,1.41,529,207,85,0.75,62,6654,3.5,6.8,35,4.05,0.12,0.023,0.01,1.4,250,2.5,55.5,100,52.16,10.55,0.55,60,3.6,4.288,0.28,0.075,0.122,0.048,192,3,160,0.9,1.62,0.104,4.235), "Mass"
=  c(44.5,15.5,8.1,423,119.5,115,98.2,5.5,58,6.4,4,5.7,6.6,0.14,1,10.8,12.3,6.3,4603,0.3,419,655,3.5,115,25.6,5,17.5,680,406,325,12.3,1320,5712,3.9,179,56,17,1,0.4,0.25,12.5,490,12.1,175,157,440,179.5,2.4,81,21,39.2,1.9,1.2,3,0.33,180,25,169,2.6,11.4,2.5,50.4))
print(Matrix_1)
ggplot(Matrix_1, aes(size, Mass))+
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
#        size    Mass
# 1     3.385   44.50
# 2     0.480   15.50
# 3     1.350    8.10
# 4   465.000  423.00
# 5    36.330  119.50
# 6    27.660  115.00
# 7    14.830   98.20
# 8     1.040    5.50
# 9     4.190   58.00
# 10    0.425    6.40
# 11    0.101    4.00
# 12    0.920    5.70
# 13    1.000    6.60
# 14    0.005    0.14
# 15    0.060    1.00
# 16    3.500   10.80
# 17    2.000   12.30
# 18    1.700    6.30
# 19 2547.000 4603.00
# 20    0.023    0.30
# 21  187.100  419.00
# 22  521.000  655.00
# 23    0.785    3.50
# 24   10.000  115.00
# 25    3.300   25.60
# 26    0.200    5.00
# 27    1.410   17.50
# 28  529.000  680.00
# 29  207.000  406.00
# 30   85.000  325.00
# 31    0.750   12.30
# 32   62.000 1320.00
# 33 6654.000 5712.00
# 34    3.500    3.90
# 35    6.800  179.00
# 36   35.000   56.00
# 37    4.050   17.00
# 38    0.120    1.00
# 39    0.023    0.40
# 40    0.010    0.25
# 41    1.400   12.50
# 42  250.000  490.00
# 43    2.500   12.10
# 44   55.500  175.00
# ...

# %% [markdown]
# ## Question 8

# %%
mass_log_10 <- log10(Matrix_1$Mass)
Matrix_2 <-  cbind(Matrix_1, mass_log_10)
size_log_10 <- log10(Matrix_2 $size)
Matrix_3 <- cbind(Matrix_2, size_log_10)

ggplot(Matrix_3, aes(size_log_10, mass_log_10))+
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)+
  scale_x_log10()+
  scale_y_log10()
# Out:
# Warning message in self$trans$transform(x):
# "NaNs produced"Warning message:
# "Transformation introduced infinite values in continuous x-axis"Warning message in self$trans$transform(x):
# "NaNs produced"Warning message:
# "Transformation introduced infinite values in continuous y-axis"Warning message in self$trans$transform(x):
# "NaNs produced"Warning message:
# "Transformation introduced infinite values in continuous x-axis"Warning message in self$trans$transform(x):
# "NaNs produced"Warning message:
# "Transformation introduced infinite values in continuous y-axis"`geom_smooth()` using formula 'y ~ x'
# Warning message:
# "Removed 21 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 20 rows containing missing values (geom_point)."
# plot without title
